# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# %%
dados = pd.read_csv("historico_petroleo.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11082 entries, 0 to 11081
# Data columns (total 2 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   data                        11082 non-null  object
#  1   preco_petroleo_bruto_brent  11082 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 173.3+ KB

# %%
dados["data"] = pd.to_datetime(dados["data"])#.dt.date
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11082 entries, 0 to 11081
# Data columns (total 2 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   data                        11082 non-null  datetime64[ns]
#  1   preco_petroleo_bruto_brent  11082 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 173.3 KB

# %%
dados.head()
# Out:
#         data  preco_petroleo_bruto_brent
# 0 2024-01-08                       75.47
# 1 2024-01-05                       78.31
# 2 2024-01-04                       75.79
# 3 2024-01-03                       77.18
# 4 2024-01-02                       76.24

# %%
dados['data'].min()
# Out:
# Timestamp('1987-05-20 00:00:00')

# %%
start_date = '1987-07-01'
end_date = '1999-12-31'
dados_filt = dados[dados["data"]] == start_date
dados_filt.head()
# Out:
# C:\Users\henri\AppData\Local\Temp\ipykernel_5436\240301586.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dados_filt = dados[dados["data"]] = start_date
# C:\Users\henri\AppData\Local\Temp\ipykernel_5436\240301586.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dados_filt = dados[dados["data"]] = start_date
# ...
